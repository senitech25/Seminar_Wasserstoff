# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('S2_Strombilanz_monatlich.csv')

# Display the first 5 rows of the data
df.head(20)
# Out:
#         Monat     Bilanz
# 0      Januar -819612.24
# 1     Februar -480470.72
# 2        März -180755.67
# 3       April  123061.02
# 4         Mai  107110.68
# 5        Juni  136107.79
# 6        Juli  205982.08
# 7      August   53414.82
# 8   September -193914.20
# 9     Oktober -498487.88
# 10   November -737355.43
# 11   Dezember -886759.59

# %%
df['Bilanz']=df['Bilanz']/1000
df
# Out:
#         Monat     Bilanz
# 0      Januar -819.61224
# 1     Februar -480.47072
# 2        März -180.75567
# 3       April  123.06102
# 4         Mai  107.11068
# 5        Juni  136.10779
# 6        Juli  205.98208
# 7      August   53.41482
# 8   September -193.91420
# 9     Oktober -498.48788
# 10   November -737.35543
# 11   Dezember -886.75959

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 5))

# create a new column to indicate whether the Bilanz is positive or negative
df['color'] = df['Bilanz'].apply(lambda x: '#77DD77' if x >= 0 else '#FF6961')

# create the bar plot
bars=plt.bar(df['Monat'], df['Bilanz'], color=df['color'])

# add a horizontal line at y=0
plt.axhline(y=0, color='black', linewidth=1)

# set the x-label and y-label
plt.xlabel('Monat')
plt.title('monatliche Strombilanz [MWh]')

# set the x-tick labels to be rotated by 60 degrees
plt.xticks(rotation=60)

# show the plot
plt.show()
