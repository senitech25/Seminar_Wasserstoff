# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('Strombilanz_monatlich.csv')

# Display the first 5 rows of the data
df.head(20)
# Out:
#         Monat      Bilanz
# 0      Januar  -514057.61
# 1     Februar   -58537.59
# 2        März   493527.64
# 3       April   948552.88
# 4         Mai   948855.13
# 5        Juni   968928.27
# 6        Juli  1103264.51
# 7      August   864997.25
# 8   September   447346.13
# 9     Oktober   -12551.46
# 10   November  -410303.51
# 11   Dezember  -618922.93

# %%
df['Bilanz']=df['Bilanz']/1000
df
# Out:
#         Monat      Bilanz    color
# 0      Januar  -514.05761  #FF6961
# 1     Februar   -58.53759  #FF6961
# 2        März   493.52764  #77DD77
# 3       April   948.55288  #77DD77
# 4         Mai   948.85513  #77DD77
# 5        Juni   968.92827  #77DD77
# 6        Juli  1103.26451  #77DD77
# 7      August   864.99725  #77DD77
# 8   September   447.34613  #77DD77
# 9     Oktober   -12.55146  #FF6961
# 10   November  -410.30351  #FF6961
# 11   Dezember  -618.92293  #FF6961

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 5))

# create a new column to indicate whether the Bilanz is positive or negative
df['color'] = df['Bilanz'].apply(lambda x: '#77DD77' if x >= 0 else '#FF6961')

# create the bar plot
bars=plt.bar(df['Monat'], df['Bilanz'], color=df['color'])

# add a horizontal line at y=0
plt.axhline(y=0, color='black', linewidth=1)

# set the x-label and y-label
plt.xlabel('Monat')
plt.title('monatliche Strombilanz [MWh]')

# set the x-tick labels to be rotated by 60 degrees
plt.xticks(rotation=60)

# show the plot
plt.show()
